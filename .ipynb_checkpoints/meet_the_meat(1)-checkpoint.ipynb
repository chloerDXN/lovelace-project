# %% [markdown]
# # Meet the meat

# %% [markdown]
# ## Abstract
#
# With increasingly dire climate change forecasts, concerned individuals are asking how they can minimize their carbon footprint. Recent research suggests that reducing one's consumption of meat, in particular beef, is one of the highest impact actions an individual can take. To examine this topic, we will explore the popularity and prevalence of meat in recipes. Specifically, we plan to extract the ingredients from a recipe database and calculate the carbon footprint of recipes
#
# Finally, we hope to directly relate this data to the issue of climate change by estimating a rating reflecting the carbon footprint of meat in recipes and the environmental impact of consumers' diets.

# %% [markdown]
# ### Imports and libraries

# %%
# Import libraries
import re
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import os, os.path as osp

# %%
DATA_FOLDER='data'
SAMPLE_DATA_FOLDER = DATA_FOLDER + '/sample_400/'

# %% [markdown]
# ## Data extraction and cleaning
#
# Our recipe dataset contains recipes from the [From Cookies to Cooks](http://infolab.stanford.edu/~west1/from-cookies-to-cooks/), combining recipes from 14 high-traffic websites. We start by extracting all the information we want from the HTML files, that is: title, ingredients and meat or animal protein ingredients, tags, ratings in order to explore the recipes in more detail.

# %% [markdown]
# #### Recipe webpage scraping
# The websites' HTML sources are rich in information. However, the information we wantfrom these pages is rather limited. We extract the information we need from the websites, clean and pre-process the data and save it as a CSV file for easy retrieval in further processing.

# %%
def analyse_page(soup, page):
    """
    Input: 
        soup
        page: 'allrecipes', 'epicurious', 'food_network', 'food_com', 'betty_crocker', 'my_recipes' , others not implemented yet
    
    Output:
        tags = list of tags assigned to the recipe
        ings = list of ingredients
    """
    ings = []
    tags = []
    if page == 'allrecipes':
        # Extract tags
        tag_wrappers = soup.find_all(itemprop="recipeCategory")
        for tag in tag_wrappers:
            tags.append(tag['content'])           
        # Extract ingredients
        ing_wrap=soup.find_all('li', class_="plaincharacterwrap ingredient")
        if ing_wrap:
            for ing in ing_wrap:
                ings.append(ing.getText())
        else:##?
            ing_wrap=soup.find_all(itemprop="recipeIngredient")

            for ing in ing_wrap:
                ings.append(ing.getText())
            if not ing_wrap:
                print('alternative format needed for Allrecipes')
        
        
    elif page == 'epicurious':       
        # Extract tags
        tag_wrappers = soup.find_all(itemprop="recipeCuisine")
        for tag in tag_wrappers:
            tags.append(tag.getText())    
        tag_wrappers = soup.find_all(itemprop="recipeCategory")
        for tag in tag_wrappers:
            tags.append(tag.getText())        
        # Extract ingredients
        ing_wrap=soup.find('div', id="ingredients")
        for ing in ing_wrap:
            ings.append(ing.string)
      
    
    elif page == 'food_network':  
        # Extract tags
        tag_wrappers = soup.find_all(class_="btn grey-tags")        
        for tag in tag_wrappers:
            tags.append(tag.getText())      
        # Extract ingredients
        ing_wrap=soup.find_all('li',class_='ingredient')
        for ing in ing_wrap:
            ings.append(ing.text)

    elif page == 'food_com':      
        # Extract tags
            #not found          
        # Extract ingredients
        ing_wrap=soup.find_all('li', class_="ingredient")
        if ing_wrap:
            for ing in ing_wrap:
                ings.append((ing.find('span',class_='value').text+ ' '+ing.find('span',class_='type').text + ' ' + ing.find('span', class_='name').text))
        else:
            ing_wrap=soup.find_all(class_="name")
            for ing in ing_wrap:
                ings.append(ing.getText())
    
    elif page == 'betty_crocker':   
        # Extract tags
            #not found    
        # Extract ingredients
        ing_wrap=soup.find_all('dl', class_='ingredient')
        for ing in ing_wrap:
            ings.append(ing.getText())
    
    
    elif page == 'my_recipes':
        # Extract tags
        tag_wrappers = soup.find_all(itemprop="recipeType")
        for tag in tag_wrappers:
            tags.append(tag.getText())  
        # Extract ingredients
        ing_wrap=soup.find_all(itemprop="ingredient")
        for ing in ing_wrap:
            ings.append(ing.text)
        
    #other websites    
        # Extract tags   
        # Extract ingredients 
        
    if not ing_wrap:  #return warning if website is recognized but format/data extraction is not successful
        print('*******')
        print('NEED NEW FORMAT')  
        print('*******')
    
    #if not tags:
        #print('no tags found :( ')
        
    return tags, ings#, ing_amnts

# %%
def find_website(soup):
    """
    Finds if the page is a recipe and which website it comes from
    """
    is_recipe = True
    
    if 'Allrecipes' in soup.title.string:
        website = 'allrecipes'               
              
    elif 'Epicurious' in soup.title.string:
        website = 'epicurious'
    
    elif 'Food Network' in soup.title.string:
        website = 'food_network'
        
    elif 'Food.com' in soup.title.string:
        website == 'food_com'
    
    elif 'Betty Crocker' in soup.title.string:
        website = 'betty_crocker'
               
    elif 'MyRecipes' in soup.title.string:
        website = 'my_recipes'

    else:
        website = 'not found'
        is_recipe = False
        
    return is_recipe, website

# %% [markdown]
# #### Quantity extraction and conversion
# The amounts of each ingredients are expressed in many different units (imperial or metric) depending on the websites, and even on the recipes. Once we have extracted the ingredients and amounts, we need to convert all different quantities to one single weight unit (fixed to kilograms) in order to process the carbon footprint of selected ingredients.

# %%
def check_quantity(quant_str):
    """
    Cleans input string and extracts numerical values
    Outputs cleaned string, array of numerical values and sum of numerical values
    """
    quant_str=quant_str.replace("½",".5")
    quant_str=quant_str.replace("1/2",".5")
    quant_str=quant_str.replace("1/3", '.33')
    quant_str=quant_str.replace('1/4','.25')
    quant_str=quant_str.replace('3/4','.75')
    quant_vals=re.findall(r"[-+]?\d*\.\d+|\d+", quant_str)
    total_quant=np.sum([float(i) for i in quant_vals])
    
    return quant_str, quant_vals, total_quant


def convert_to_kg(quant, unit):
    """
    Converts any input unit (kg, lb, grams, ounces) to kilograms
    """
    
    if (unit=='kilogram') or (unit=='kg'):
        amnt_kg=quant
        #print(quant,'kg')
    elif (unit=='pound') or (unit=='lb') or (unit=='lbs') or (unit=='pounds'):
        amnt_kg=quant/2.205
        #print(amnt_kg,'kg')
    elif(unit=='g') or (unit=='gram') or (unit =='grams'):
        amnt_kg=quant/1000
        #print(amnt_kg,'kg')     
    elif(unit=='oz') or (unit=='ounce'):
        amnt_kg=quant/35.274
        #print(amnt_kg, 'kg')
        
    return(amnt_kg)

def contains_meat_ingredients(ings_in, meat_products_in):
    contains_meat=False
    meat_ingredients=[]
    meat_ingredients_str=[]
    #meat_ingredients=[False]*len(meat_products_in)
    for i in ings_in:
        for meat_product in meat_products_in:
            if i != None:
                if meat_product in i.casefold(): 
                    contains_meat=True
                    meat_ingredients.append(meat_product) 
                    meat_ingredients_str.append(i)
                    
    return contains_meat, meat_ingredients, meat_ingredients_str

def extract_meat(meat_ings_str):
    """
    Inputs: 
    ings_in= list of ingredients (and quantities)
     
    Outputs:
    ing_amnt_out = list of corresponding quanities of meat ingredients in kg (=0 if unit not recognized)
    
    """

    ing_amnt_out=[]
   
    #extract amount from string and convert to kg
    for meat_i in meat_ings_str:
        meat_i_quant_kg=0
        meat_i, quantity_vals, total_quantity=check_quantity(meat_i) #pass string, return cleaned string and total quantity

        for u in units: 
            if u in meat_i:
                meat_i_quant_kg = convert_to_kg(total_quantity,u)
        ing_amnt_out.append(meat_i_quant_kg)
        #if meat_i_quant_kg==0:
        #    print('Units not recognized for: '+meat_i)
                    
    return ing_amnt_out

# %% [markdown]
# #### Define carbon footprint of meat ingredients
# Animal agriculture is one of the leading sources of the carbon-impact of a recipe. We start by assigning a carbon footprint to each meat ingredient and could later on extend it to other animal products.
# The functions below assign a carbon footprint to each meat ingredient of the recipes.
#
# Source of data: [GreenEatz](https://www.greeneatz.com/foods-carbon-footprint.html)

# %%
#Load data from xls file
carbon_footprint = pd.read_excel('data/carbon_footprint_protein.xls', sheet_name='meat_dairy_eggs', index_col=0)
carbon_footprint
# Out:
#          Food  CO2 Kilos Equivalent  Car Miles Equivalent
# Rank
# 1        Lamb                  39.2                    91
# 2        Beef                  27.0                    63
# 3      Cheese                  13.5                    31
# 4        Pork                  12.1                    28
# 5      Turkey                  10.9                    25
# 6     Chicken                   6.9                    16
# 7        Tuna                   6.1                    14
# 8        Eggs                   4.8                    11

# %%
#List of meat ingredients
meat_products = carbon_footprint['Food'].tolist()
#same list copied without caps
meat_products = ['lamb', 'beef', 'cheese', 'pork', 'turkey', 'chicken', 'tuna', 'egg']

# %%
units = ['pounds','grams','oz','ounces','kg','kilograms','lbs' ]

# %%
# calculate carbon footprint
#input ingredients and amounts
#output carbon footprint
def carbon_fp (l):
    """
    takes a list of ingredients contributing to co2 and returns carbon footprint
    """
    c=len(l)
    return c

# %% [markdown]
# ### Data extraction and cleaning loop
# Below we extract the data from the recipes of our html dataset and save it in dataframes. Our goal here is to extract the ingredients and assign a carbon-impact rating to the highest impact ingredients (meat or animal protein) in the recipes.
#
# To extract protein-rich ingredients from animal source in order to calculate the main carbon footprint of the recipe, we use an extra database listing the main protein sources and carbon impact. Source of data: [GreenEatz](https://www.greeneatz.com/foods-carbon-footprint.html)

# %%
#Loop for all recipes in folder
# data has following row structure
# RecipeName as Identifier - bool contains_meat - list of co2 ingredients - carbonFootprint - ingredients
data=[]
step=0

verbose = 0 #verbose outputs

for filename in os.listdir(SAMPLE_DATA_FOLDER):
    with open(SAMPLE_DATA_FOLDER+filename) as f:
        isTrue=False
        count_exceptions=0
        print('----------------------------------')
        try:
            page = f.read()
            soup = BeautifulSoup(page, 'html.parser')
            
            #check webpage and extract ingredients if recognised as recipe
            is_recipe, website = find_website(soup)
            print('This recipe is',soup.title,' from: '+website)            
            
            if is_recipe:

                #tags, ingredients = analyse_page(soup, website)
                tags, ingredients= analyse_page(soup, website)
                
                if ingredients:
                    
                    
                    has_meat, meat_ingredients, meat_ingredients_str = contains_meat_ingredients(ingredients, meat_products)
                    
                    if has_meat:

                        #Extract all ingredients (and ingredient amounts if available)
                        #Extract meat ingredients and quantities in kg
                        #print('ingredient ammount = ', ingredient_amounts)
                        ingredient_quant_kg = extract_meat(meat_ingredients_str)
                        print('does this recipe contain meat? ', contains_meat)
                        print('ingredients = ',ingredients)
                        print('meat ingredients=', meat_ingredients_str)
                        print('ingredient_quantity (kg)= ',ingredient_quant)
                        

                    if verbose: 
                        
                        print('does this recipe contain meat? ', contains_meat)
                        print('ingredients = ',ingredients)
                        print('meat ingredients=', meat_ingredients_str)
                        print('ingredient_quantity (kg)= ',ingredient_quant)
                        print('Recipe Analysed: '+soup.title.string)
                        
                        print('contains meat:'+str(has_meat))
                        print(meat_ingredients)
                        
                        print('{0} Ingredients: '.format(len(ingredients)))
                        print(ingredients)

                        print('{0} tags:'.format(len(tags)))
                        print(tags)
                            
                data.append([soup.title.string, has_meat, meat_ingredients, tags])

            #else:
                #print('not a recipe')
        except:
            count_exceptions=count_exceptions+1
            #print('Exception')
    step=step+1
    
    if verbose: 
        print('-------------------------------------')
        
#    if step>=100:
#        break

column_labels=['Recipe Title', 'Has meat', 'Meat types', 'Tags']#missing: 'Carbon footprint', 'Rating', 'Tags'
recipes_df = pd.DataFrame(data, columns = column_labels)

#save the data as csv for in depth analysis
recipes_df.to_csv(DATA_FOLDER+'/recipes_data')

recipes_df
# Out:
# ----------------------------------
# This recipe is <title>Money-Saving Meals : Recipes and Cooking : Food Network</title>  from: food_network
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Cheese and Onion Pie Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Wonton Wrappers Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Cinnamon Bun Scones Recipe #68967 from CDKitchen.com</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Twice Baked Cheesy Potatoes Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
#
#
#
#
#
#
#
#
#
# Vegetable Platter with Cannellini "Hummus" Recipe Reviews by Epicurious.com Members, Page  1
# </title>  from: epicurious
# ----------------------------------
# This recipe is <title>
# 	Mahi Mahi with Coconut Rice and Mango Salsa Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Coconut Icebox Cookies Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
#
#
#
#
#
#
#
#
#
# Harissa-Crusted Tri-Tip Roast Recipe
#  at Epicurious.com</title>  from: epicurious
# ----------------------------------
# This recipe is <title>Canning Cucumbers Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Pork Recipes - Pork Roasts, Ribs, Pork Loin, Pork Chops, Pork Tenderloin, and More</title>  from: not found
# ----------------------------------
# This recipe is <title>Savory Grilled Chicken Sauce Recipe : Paula Deen : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Tisane Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>
# 	Chive Mushroom Soup Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Seattle Dutch Babies Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Baked Asparagus with Balsamic Butter Sauce Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Sausage-Hash Brown Breakfast Casserole Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>Chocolate-Coated Caramel Corn Recipe from CDKitchen.com</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Stuffed Mushrooms with Spinach Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Oyster Stew Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Great Recipes, Dinner Ideas and Quick &amp; Easy Meals from Kraft Foods</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Slow Cooker Carnitas Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Have you eliminated gluten (a protein found in wheat, barley and rye) from your diet?  | Eating Well</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Mango Cake  - All recipes Australia NZ
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Inside Out Stuffed Peppers Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Can you use butter in brownies instead of oil - CookEatShare</title>  from: not found
# ----------------------------------
# This recipe is <title>Calories in Dead Simple, Vegan, Fat-Free Pea Soup - Calorie, Fat, Carb, Fiber, and Protein Info</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Progresso® Bread Crumb Recipes - Betty Crocker
# </title>  from: betty_crocker
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>RBE subscription</title>  from: not found
# ----------------------------------
# This recipe is <title>Chambord® raspberry liqueur information</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Hot cocktail recipes: 30+ appetizing drink recipes.</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Spinach And Cheese Dip Recipe | Group Recipes</title>  from: not found
# ----------------------------------
# This recipe is <title>Simple Collard Greens Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>
# 	Perfect Pumpkin Pie Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Cranberry Sauce I Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Calories in Simple Barley Pudding - Calorie, Fat, Carb, Fiber, and Protein Info</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Can people with wheat allergies eat quinoa - CookEatShare</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>White Chocolate Bark Recipe : Ina Garten : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Smothered Chicken - Recipe.com</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Shortening Substitute | Taste of Home Cooking-Tips
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
#
#
#
#
#
#
#
#
#
# Espresso and Mascarpone Icebox Cake Recipe
#  at Epicurious.com</title>  from: epicurious
# ----------------------------------
# This recipe is <title>
# 	Halloween Cookies Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Biscotti recipes  - All recipes UK
# </title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Loaded Twice-Baked Potatoes Recipe | Eating Well</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Ginger Iced Tea Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Cranberry-Brie Phyllo Triangles Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Liver Pate Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	bush tucker pictures - All recipes Australia NZ
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Cooks.com - Recipes - Easy Pancakes</title>  from: not found
# ----------------------------------
# This recipe is <title>Rolled Turkey Breast With Pancetta, Figs And Leek Recipe - Taste.com.au</title>  from: not found
# ----------------------------------
# This recipe is <title>Baby Shower Menu Ideas - Food and Recipes for Baby Showers - Delish.com</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Spiced Chicken Tenders with Dipping Sauces Recipe : Sandra Lee : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>
# 	Chicken Corn Chowder Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Pineapple Angel Food Cake I Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Asian Egg Drop Soup Recipe : Tyler Florence : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>
# 	Asian Ground Beef and Pepper Saute Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Jello poke cake using a 13 x 9 x 2 pan - CookEatShare</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Slow Cooker Lentil Soup  Recipe from Betty Crocker
# </title>  from: betty_crocker
# ----------------------------------
# This recipe is <title>Turtle Candy Cake Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Grilled Romaine Lettuce Recipe</title>  from: not found
# ----------------------------------
# This recipe is <title>Skewer Recipes for the Grill - Recipes for Grilling Skewers and Kebobs - Delish.com</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Nancy's Chicken in Puff Pastry Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Fruit Dip Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
#
#
#
#
#
#
#
#
#
# Fast White-Bean Stew Recipe
#  at Epicurious.com</title>  from: epicurious
# ----------------------------------
# ----------------------------------
# This recipe is <title>Ginger Spiced Mashed Sweet Potatoes Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Seven Minute Frosting I Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Moroccan Spiced Chickpea Soup Recipe : Dave Lieberman : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>Butternut Squash Recipes - MyRecipes.com</title>  from: my_recipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# ----------------------------------
# This recipe is <title>Lucky Foods - Good Luck New Years Food - Delish.com</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Wild Rice Pilaf Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Southern Fried Corn Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Pumpkin Pound Cake Recipe : George Stella : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Swiss Steak Ground Beef Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Brussels Sprouts With Balsamic Vinegar Recipe</title>  from: not found
# ----------------------------------
# This recipe is <title>Duck Soup Recipe</title>  from: not found
# ----------------------------------
# This recipe is <title>Swimming Pool (Cocktail) Recipe | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Porchetta Abbruzzese, Spiendini Misti And Rib of Beef | BigOven
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Lentil Salad with Feta Cheese Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Breaded Fish Gluten Free Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Oreo Fluff Recipe - RecipeTips.com</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Margaritas on the Rocks Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Pecan Pie Recipes - Southern Pecan Pie Recipe - Delish.com</title>  from: not found
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Easy Meatballs  Recipe from Betty Crocker
# </title>  from: betty_crocker
# ----------------------------------
# This recipe is <title>
# 	Christmas puddings  - All recipes UK
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Pumpkin Loaf Recipes</title>  from: not found
# ----------------------------------
# This recipe is <title>Turkey Piccata Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>Cooking from the Pantry : Recipes and Cooking : Food Network</title>  from: food_network
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
# 	Apple Squares Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Baked Ziti Recipe : Rachael Ray : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Cooks.com - Recipes - Flavored Whipped Cream Topping</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# Grilled Potatoes with Garlic Aioli Recipe -
# Jody Denton
#  | Food &amp; Wine
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Sesame Chicken Dip Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Salad Recipes</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Enchilada Lasagna Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Best Ever Popcorn Balls Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Oxtail Stew Recipe : Emeril Lagasse : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Coconut Marshmallow Cream Meringue Pie Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Fresh Tasting Black Beans With Rice Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Spicy Bok Choy in Garlic Sauce Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Perfect Baked Potato Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Pork Baby Back Rib Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
# 	Chicken Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>Marie Callender's Recipes - CDKitchen</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Bruschetta Chicken Bake Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Moravian Spice Cookies Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Halloween Cupcakes - Cupcakes Recipes - Delish.com</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
#
#
#
#
#
#
#
#
#
# Homemade Chai Recipe
#  at Epicurious.com</title>  from: epicurious
# ----------------------------------
# ----------------------------------
# This recipe is <title>Calories in HCG Grissini (breadsticks) - Calorie, Fat, Carb, Fiber, and Protein Info</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Seared Tuna with Wasabi-Butter Sauce Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Scottish Shortbread IV Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Scalloped Potatoes with Ham - Crockpot Scalloped Potato Recipes</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Cooks.com - Recipes - Salmon Sandwich</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Old-Fashioned Carrot Cake Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Grilled Burger Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>Homemade Honeycomb Recipe - Taste.com.au</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Peach Tea Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Healthy Catfish Recipes | Eating Well</title>  from: not found
# ----------------------------------
# This recipe is <title>Ceebu Jen Recipes | ifood.tv</title>  from: not found
# ----------------------------------
# This recipe is <title>Easy Corned Beef and Cabbage Recipe : Paula Deen : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>
# 	Veggie Lover's Baked Ziti Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Green Beans with Shallots Recipe : Food Network Kitchens : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>
# 	Chicken Avocado Pizza Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Ham Sandwich Recipes - CDKitchen</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Baked Fish with Cheese Sauce Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Easy Baking Recipes, Tips and Ideas from BettyCrocker.com
# </title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Israeli Moroccan Couscous Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Pesto Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Japanese Ginger Salad Dressing Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Easy Cheesecake  Recipe from Betty Crocker
# </title>  from: betty_crocker
# ----------------------------------
# This recipe is <title>Pumpkin Mousse Dessert Parfait recipes    </title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Easiest Ever Christmas Dinner Menu</title>  from: not found
# ----------------------------------
# This recipe is <title>Tony's Chocolate Pecan Pie Recipe : Patrick and Gina Neely : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Smothered Mushrooms and Kale Recipe : Rachael Ray : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Shrimp and Grits Recipe : Patrick and Gina Neely : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Zesty Vegetarian Wraps Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	More Recipes Like Vegetarian Stuffing - All Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Simple Cajun Seasoning Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Artichoke Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>French Toast Recipes</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Fried Chicken Tenders Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Spinach Rice Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Orange Cream Cheese Frosting Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Cranberry-Almond Coleslaw Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Baked Acorn Squash Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>swordfish steak recipe Recipes at Epicurious.com</title>  from: epicurious
# ----------------------------------
# This recipe is <title>Cheesy Ham and Banana Casserole Recipe : Paula Deen : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Spinach Cheese Squares Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Bread Machine Bagels Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Creamed Spinach Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Chinese Broccoli Slaw Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Strawberry Shortcake Trifle Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>
# 	Zucchini and Blue Cheese Side Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Best turkey meatloaf recipe - CookEatShare</title>  from: not found
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
#
#
#
#
#
#
#
#
#
# Grilled Rib-Eye Steaks with Parsley-Garlic Butter Recipe
#  at Epicurious.com</title>  from: epicurious
# ----------------------------------
# This recipe is <title>Carolina Baked Dressing Recipe from CDKitchen.com</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Gourmet Sweet Potato Classic Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Thumbprint Cookies  Recipe from Betty Crocker
# </title>  from: betty_crocker
# ----------------------------------
# This recipe is <title>Peach Crisp Recipe : Anne Burrell : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>Pumpkin Bread Recipe : Alton Brown : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Pumpkin Oatmeal Recipe : Aarti Sequeira : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>For a Crowd : recipes and cooking : Food Network : Recipes and Cooking : Food Network</title>  from: food_network
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
# 	Apple Pie Bars Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Authentic Korean Bulgogi Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Red Beans and Rice Recipe : Alton Brown : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Easy Creamy Chicken Pasta recipe - Best Recipes</title>  from: not found
# ----------------------------------
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Fresh Pineapple Upside Down Cake Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Lemon Wasabi Sauce Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Home-made Beef Pepperoni Recipe</title>  from: not found
# ----------------------------------
# This recipe is <title>Legspreader drink recipes</title>  from: not found
# ----------------------------------
# This recipe is <title>Eggplant Peppers Squash Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Fry Bread I Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Hash Brown Casserole with Bacon, Onions, and Cheese Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>
# 	Apple Pork Chop Casserole Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Best Chili Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>White Chocolate-Cream Cheese Frosting recipe</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Green Bean Casserole  Recipe from Betty Crocker
# </title>  from: betty_crocker
# ----------------------------------
# This recipe is <title>
# 	Tomato Mozzarella Salad Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Potato Gnocchi Bake Recipe - Taste.com.au</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Fresh Corn Chowder Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
#
#
#
#
#
#
#
#
#
# Menu with recipes for A Delicious Christmas Eve Buffet
#  at Epicurious.com</title>  from: epicurious
# ----------------------------------
# This recipe is <title>
# 		Chargrilled Beef Salad with Thai Dressing recipe – All recipes Australia NZ
# 	</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	More Recipes Like Green Salsa - All Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Chicken Enchiladas Cream Chicken Soup Recipe | Group Recipes</title>  from: not found
# ----------------------------------
# This recipe is <title>Basketball Party Recipes</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Stuffed Portobello Mushrooms Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	S'mores Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Zucchini, Chicken and Rice Casserole Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Pasta with Tomato Basil Cream Sauce | BigOven
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Cooks.com - Recipes - Hog Head Cheese</title>  from: not found
# ----------------------------------
# This recipe is <title>Weekly Dinner Planner: 7 Nights of Recipes for Planning Your Grocery Shopping | Food | Disney Family.com</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Recipe.com</title>  from: not found
# ----------------------------------
# This recipe is <title>Peppermint schnapps information</title>  from: not found
# ----------------------------------
# This recipe is <title>Healthy Diet - Budget Menus - Delish.com</title>  from: not found
# ----------------------------------
# This recipe is <title>Whole Wheat Molasses Bread Recipe</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Hot German Potato Salad III Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Dessert, Gourmet Dessert Recipes, Cake Recipes, Easy Dessert Recipes, Gourmet Dessert Recipes with Pictures, Chocolate Dessert Recipes, Strawberry Desserts, Photographs</title>  from: not found
# ----------------------------------
# This recipe is <title>Ricotta Cheese Low Carb Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Individual Beef Wellingtons Recipe : Emeril Lagasse : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Boiled Salad Dressing recipe - Best Recipes</title>  from: not found
# ----------------------------------
# This recipe is <title>Grilled Lamb Chops Recipe : Giada De Laurentiis : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>Shrimp Salad Recipe - Recipe for Shrimp Salad with Celery and Mayonnaise</title>  from: not found
# ----------------------------------
# This recipe is <title>Paula's Southern Thanksgiving : Special : Food Network</title>  from: food_network
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>Bottom Round Roast, Beef - Definition and Cooking Information - RecipeTips.com</title>  from: not found
# ----------------------------------
# This recipe is <title>Cornbread &amp; Apple Stuffing Recipe | Eating Well</title>  from: not found
# ----------------------------------
# This recipe is <title>Chef Stuart's Maryland Crab Soup Recipe :   : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>Lasagna Rolls Recipe : Giada De Laurentiis : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Poppy Seed Dressing I Recipe Reviews - Allrecipes.com (Pg. 1)
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
# 	Crescent Chicken Bundles Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Fat Free Egg Roll Recipes | ifood.tv</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Everyday Leftovers - Pasta Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>Sweet Potato Facts, Selection, and Storage</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Chicken Breast Cutlets with Artichokes and Capers Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Asian Pasta Salad Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Cooks.com - Recipes - Crescent Roll Dessert</title>  from: not found
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Peanut Cake Squares Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Cooks.com - Recipes - Steak For Swissing</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Sunrise Salad Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Appetizer Recipes By Kraft Foods - Cold &amp; Hot Appetizers: Easy Snack Recipes &amp; Party Appetizers</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Grilled Asparagus Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Christmas Side Dish Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
# 	More Recipes Like Sweet Potato Corn Bread - All Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Peas and Carrots Spring Salad Recipe : Rachael Ray : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>Cooks.com - Recipes - Clam Boil</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Cinnamon Chip Apple Cookies Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	No-Bake Cereal Bars Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Hummus Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>Scallop Fakes and Scallop Types</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Detox Salad Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>Montanas four cheese spinach dip recipe - CookEatShare</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Slow Cooker Buffalo Chicken Sandwiches Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Low Calorie Turkey Gravy Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Porchetta with Roasted Fingerlings Recipe : Anne Burrell : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>
# 	Cajun Appetizer Meatballs Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Pumpkin Muffins Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>Pantry Essentials Checklist | MyRecipes.com</title>  from: my_recipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# ----------------------------------
# This recipe is <title>Pea And Ham Soup Recipe - Taste.com.au</title>  from: not found
# ----------------------------------
# This recipe is <title>Uncooked Cranberry and Orange Relish Recipe : Michele Urvater : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Gluten Free Tomato Bisque Soup Recipes | Yummly</title>  from: not found
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>Authentic chimichurri recipe - CookEatShare</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Gingerbread Cupcakes Cake Mix Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Easy Baked Tilapia Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Is Stevia Safe? | Eating Well</title>  from: not found
# ----------------------------------
# This recipe is <title>Frozen Peaches Recipe : Alton Brown : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>
# 	Herbs and Spice Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>The Creamiest No Cook Peanut Butter Fudge Recipe from CDKitchen.com</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	No Tomato Chili Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Vietnamese Vegetable Egg Roll Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Healthy Low-Calorie Chicken Recipes | Eating Well</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Pumpkin Oatmeal Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Jerky Lover's Jerky - Sweet, Hot and Spicy! Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Gluten-Free Cheese and Herb Pizza Crust Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Blackened Tilapia with Secret Hobo Spices Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Raspberry Sauce Recipe : Ina Garten : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>
# 	Flourless Chocolate Cake I Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Tomato Mac and Cheese Recipe : Paula Deen : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	More Recipes Like Flat Dumplings - All Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Perfect Fudge Article - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>pork loin Recipes at Epicurious.com</title>  from: epicurious
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>Monday Morning Potato Rolls and Bread Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Eggplant Sandwiches Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Soy Patties</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Best Vegetarian Soups, Stews &amp; Chili Recipes - Allrecipes.com
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
#
#
#
#
#
#
#
#
#
# Pumpkin Spice Bread Recipe
#  at Epicurious.com</title>  from: epicurious
# ----------------------------------
# This recipe is <title>Southern Pecan Pie Recipe</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Baked Halibut Steaks Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Lavender Syrup Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>
# 	Coconut Custard Pie II Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Asian Swordfish Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Rice and Lentil Soup in a Jar Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Brownies with Peanut Butter Fudge Frosting Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Oven-Fried Parmesan Chicken Strips Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>Grill It! with Bobby Flay : Bobby Flay : Food Network</title>  from: food_network
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
# 	Tomato Vodka Sauce Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Banana Muffins I Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Lemony Chicken Saltimbocca Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>Chinese Eggplant in Garlic Sauce Recipe from CDKitchen.com</title>  from: not found
# ----------------------------------
# This recipe is <title>Cake de Ron (Rum Cake) Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>
# 	Creamy Zucchini Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Sad Cake Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Kielbasa and Meatballs with Basil Tomatoes Recipe : Robert Irvine : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>raspberry wine jelly Recipes at Epicurious.com</title>  from: epicurious
# ----------------------------------
# This recipe is <title>Healthy Beef Stroganoff Crock Pot Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Fresh Mozzarella and Basil Pizza Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>Bruschetta with Fresh Monterey Sardines Recipe : Review :   : Recipes : Food Network</title>  from: food_network
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>
# 	Hot Bean Dip Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Sweet Potato Souffle Recipes - CDKitchen</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Monkfish Provincial Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Pepperoni Pasta Recipe | Taste of Home Recipes
# </title>  from: not found
# ----------------------------------
# This recipe is <title>Low-Carb Peanut Butter Cookies Recipe from CDKitchen.com</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Peach Crisp  Recipe from Betty Crocker
# </title>  from: betty_crocker
# ----------------------------------
# ----------------------------------
# This recipe is <title>Quick, Healthy Vegetable Recipes | Eating Well</title>  from: not found
# ----------------------------------
# This recipe is <title>Crispy and Delicious Asparagus and Potato Tart Recipe : Jamie Oliver : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# 	Authentic Italian Lasagna Recipes - Allrecipes.com (Pg. 1)
# </title>  from: allrecipes
# alternative format needed for Allrecipes
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>Vanilla Salad Dressing Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Broccoli Casserole Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Chocolate-Covered Cherry Cake Recipe :   : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Low Fat Low Calorie Frosting Recipes | Yummly</title>  from: not found
# ----------------------------------
# ----------------------------------
# ----------------------------------
# This recipe is <title>
# Cold Cucumber Soup with Mint Recipe -
# Joanne Weir
#  | Food &amp; Wine
# </title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Walnut Pie Crust Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Christmas Recipes: Appetizers, Dinner, Brunch, Desserts</title>  from: not found
# ----------------------------------
# This recipe is <title>White Pumpkin Recipe | Group Recipes</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Sweet Russian Cabbage Soup Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Apple Oatmeal Crisp Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Chocolate Chunk Cookies Recipe : Ina Garten : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Herb and Spice Guide : Recipes and Cooking : Food Network</title>  from: food_network
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>Orange Curd Recipe : Ina Garten : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Zucchini, Cherry Tomato, and Fresh Ricotta Pasta Recipe | MyRecipes.com</title>  from: my_recipes
# ----------------------------------
# This recipe is <title>Apple fritter donut recipes - CookEatShare</title>  from: not found
# ----------------------------------
# This recipe is <title>Sugar Shack : Paula's Home Cooking : Food Network</title>  from: food_network
# *******
# NEED NEW FORMAT
# *******
# ----------------------------------
# This recipe is <title>Spicy Couscous Recipe :   : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>Healthy Apple Cranberry Waldorf Salad Recipe</title>  from: not found
# ----------------------------------
# ----------------------------------
# This recipe is <title>Homemade Pappardelle Recipe : Michael Chiarello : Recipes : Food Network</title>  from: food_network
# ----------------------------------
# This recipe is <title>
# 	Garlic Mashed Potatoes Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Dried Apple Cake Or Cookies Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>
# 	Oatmeal Pancakes  Recipe from Betty Crocker
# </title>  from: betty_crocker
# ----------------------------------
# This recipe is <title>
# 	Sweet and Spicy Green Beans Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>
# 	Watergate Cake III Recipe - Allrecipes.com
# </title>  from: allrecipes
# ----------------------------------
# This recipe is <title>Orange Dreamsicle Drink Recipes | Yummly</title>  from: not found
# ----------------------------------
# This recipe is <title>Scallop Stir Fry Recipe from CDKitchen.com</title>  from: not found
#                                          Recipe Title  Has meat  \
# 0
#
#
#
#
#
#
#
#
#
# Harissa-Crusted Tri-Tip Roast Recipe...     False
# 1   Savory Grilled Chicken Sauce Recipe : Paula De...     False
# 2                       Tisane Recipe | MyRecipes.com     False
# 3
# 	Baked Asparagus with Balsamic Butter Sauce R...     False
# 4
# 	Oyster Stew Recipe - Allrecipes.com
#      False
# 5
# 	Inside Out Stuffed Peppers Recipe - Allrecip...     False
# 6
# 	Progresso® Bread Crumb Recipes - Betty Crocker
#      False
# 7        Simple Collard Greens Recipe | MyRecipes.com     False
# 8
# 	Cranberry Sauce I Recipe - Allrecipes.com
#      False
# 9   White Chocolate Bark Recipe : Ina Garten : Rec...     False
# 10
#
#
#
#
#
#
#
#
#
# Espresso and Mascarpone Icebox Cake ...     False
# 11
# 	Pineapple Angel Food Cake I Recipe - Allreci...     False
# 12
# 	Fruit Dip Recipes - Allrecipes.com
#       True
# 13
#
#
#
#
#
#
#
#
#
# Fast White-Bean Stew Recipe
#  at Epic...     False
# 14           Butternut Squash Recipes - MyRecipes.com      True
# 15
# 	Wild Rice Pilaf Recipe - Allrecipes.com
#      False
# 16
# 	Southern Fried Corn Recipe - Allrecipes.com
#      False
# 17
# 	Margaritas on the Rocks Recipe - Allrecipes....     False
# 18  Cooking from the Pantry : Recipes and Cooking ...      True
# 19
# 	Best Ever Popcorn Balls Recipe - Allrecipes....     False
# 20
# 	Fresh Tasting Black Beans With Rice Recipe -...     False
# 21
# 	Spicy Bok Choy in Garlic Sauce Recipe - Allr...     False
# 22
# 	Pork Baby Back Rib Recipes - Allrecipes.com
#       True
# 23
# 	Chicken Recipes - Allrecipes.com
#       True
# 24
# 	Moravian Spice Cookies Recipe - Allrecipes.com
#      False
# 25
#
#
#
#
#
#
#
#
#
# Homemade Chai Recipe
#  at Epicurious.com     False
# 26
# 	Scottish Shortbread IV Recipe - Allrecipes.com
#      False
# 27
# 	Grilled Burger Recipes - Allrecipes.com
#      False
# 28
# 	Peach Tea Recipe - Allrecipes.com
#      False
# 29  Green Beans with Shallots Recipe : Food Networ...     False
# ..                                                ...       ...
# 52
# 	Grilled Asparagus Recipe - Allrecipes.com
#      False
# 53
# 	Christmas Side Dish Recipes - Allrecipes.com
#      False
# 54  Peas and Carrots Spring Salad Recipe : Rachael...     False
# 55
# 	Hummus Recipes - Allrecipes.com
#       True
# 56        Pantry Essentials Checklist | MyRecipes.com      True
# 57  Uncooked Cranberry and Orange Relish Recipe : ...     False
# 58
# 	Easy Baked Tilapia Recipe - Allrecipes.com
#      False
# 59  Frozen Peaches Recipe : Alton Brown : Recipes ...     False
# 60
# 	Herbs and Spice Recipes - Allrecipes.com
#      False
# 61
# 	Pumpkin Oatmeal Recipe - Allrecipes.com
#      False
# 62
# 	Blackened Tilapia with Secret Hobo Spices Re...     False
# 63  Raspberry Sauce Recipe : Ina Garten : Recipes ...     False
# 64  Tomato Mac and Cheese Recipe : Paula Deen : Re...     False
# 65
# 	Perfect Fudge Article - Allrecipes.com
#      False
# 66
# 	Best Vegetarian Soups, Stews & Chili Recipes...      True
# 67              Lavender Syrup Recipe | MyRecipes.com     False
# 68
# 	Brownies with Peanut Butter Fudge Frosting R...     False
# 69  Grill It! with Bobby Flay : Bobby Flay : Food ...      True
# 70
# 	Creamy Zucchini Recipe - Allrecipes.com
#      False
# 71  Fresh Mozzarella and Basil Pizza Recipe | MyRe...     False
# 72  Bruschetta with Fresh Monterey Sardines Recipe...     False
# 73
# 	Monkfish Provincial Recipe - Allrecipes.com
#      False
# 74
# 	Peach Crisp  Recipe from Betty Crocker
#      False
# 75
# 	Authentic Italian Lasagna Recipes - Allrecip...      True
# 76
# 	Walnut Pie Crust Recipe - Allrecipes.com
#      False
# 77
# 	Apple Oatmeal Crisp Recipe - Allrecipes.com
#      False
# 78  Herb and Spice Guide : Recipes and Cooking : F...      True
# 79  Zucchini, Cherry Tomato, and Fresh Ricotta Pas...     False
# 80  Sugar Shack : Paula's Home Cooking : Food Network     False
# 81
# 	Sweet and Spicy Green Beans Recipe - Allreci...     False
#
#            Meat types                                               Tags
# 0                  []                                                 []
# 1                  []                                                 []
# 2                  []  [Beverages, Beverages, Nonalcoholic, Quick/Eas...
# 3                  []                                                 []
# 4                  []                                                 []
# 5                  []                                                 []
# 6                  []                                                 []
# 7                  []  [Side Dishes/Vegetables, Entertaining, Make-Ah...
# 8                  []                                                 []
# 9                  []                                                 []
# 10                 []                                                 []
# 11                 []                                                 []
# 12  [chicken, cheese]                                                 []
# 13                 []                                                 []
# 14          [chicken]                                                 []
# 15                 []                                                 []
# 16                 []                                                 []
# 17                 []                                                 []
# 18           [turkey]                                                 []
# 19                 []                                                 []
# 20                 []                                                 []
# 21                 []                                                 []
# 22           [cheese]                                                 []
# 23           [cheese]                                                 []
# 24                 []                                                 []
# 25                 []                                                 []
# 26                 []                                                 []
# 27                 []                                                 []
# 28                 []                                                 []
# 29                 []                                                 []
# ..                ...                                                ...
# 52                 []                                                 []
# 53                 []                                                 []
# 54                 []                                                 []
# 55              [egg]                                                 []
# 56         [egg, egg]                                                 []
# 57                 []                                                 []
# 58                 []                                                 []
# 59                 []                                                 []
# 60                 []                                                 []
# 61                 []                                                 []
# 62                 []                                                 []
# 63                 []                                                 []
# 64                 []                                                 []
# 65                 []                                                 []
# 66      [egg, cheese]                                                 []
# 67                 []  [Sauces/Condiments, Entertaining, Kid-Friendly...
# 68                 []                                                 []
# 69  [cheese, chicken]                                                 []
# 70                 []                                                 []
# 71                 []  [Main Dishes, Entertaining, Kid-Friendly, Quic...
# 72                 []                                                 []
# 73                 []                                                 []
# 74                 []                                                 []
# 75      [cheese, egg]                                                 []
# 76                 []                                                 []
# 77                 []                                                 []
# 78              [egg]                                                 []
# 79                 []  [Main Dishes, Kid-Friendly, Quick/Easy, Italia...
# 80                 []                                                 []
# 81                 []                                                 []
#
# [82 rows x 4 columns]
